# %% [markdown]
# ## HF Radar Compliance Checker Script
#
# ### Purpose:
# Run the compliance checker on NDBC and SIO HF radar data to compare the metadata compliance.
#
# ### Dependencies:
# This script must be run in the "I" environment for the compliance checker to work properly.
#
# Written by: JAB

# %%
# First import the compliance checker and test that it is installed properly
from compliance_checker.runner import ComplianceChecker, CheckSuite

# Load all available checker classes
check_suite = CheckSuite()
check_suite.load_all_available_checkers()

# %%
#Paths to the east coast and Gulf of Mexico 1km resolution HF Radar data 
NDBC_HFR_path = 'http://sdf.ndbc.noaa.gov/thredds/dodsC/hfradar_usegc_1km'
SIO_HFR_path = 'http://hfrnet.ucsd.edu/thredds/dodsC/HFRNet/USEGC/1km/hourly/RTV'

# %% [markdown]
# ### Running Compliance Checker on NDBC THREDDS data

# %%
# Run cf and adcc checks with normal strictness, verbose text format to stdout
return_value, errors = ComplianceChecker.run_checker(NDBC_HFR_path,
                           ['cf', 'acdd'], True, 'normal', '-', 'text')
# Out:
# --------------------------------------------------------------------------------
#                      The dataset scored 38 out of 79 points
#                              during the acdd check
# --------------------------------------------------------------------------------
#                            Verbose Scoring Breakdown:
#
#                                  High Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# Conventions                             :3:     1/2
# keywords                                :3:     0/1
# summary                                 :3:     1/1
# title                                   :3:     1/1
# varattr                                 :3:    21/37
#     DOPx                                :3:       1/3
#         var_std_name                    :3:         1/2
#         var_units                       :3:         0/1
#     DOPy                                :3:       1/3
#         var_std_name                    :3:         1/2
#         var_units                       :3:         0/1
#     lat                                 :3:       2/4
#         coverage_content_type           :3:         0/1
#         var_std_name                    :3:         1/2
#         var_units                       :3:         1/1
#     lon                                 :3:       2/3
#         var_std_name                    :3:         1/2
#         var_units                       :3:         1/1
#     procParams                          :3:       1/3
#         var_std_name                    :3:         1/2
#         var_units                       :3:         0/1
#     site_code                           :3:       1/3
#         var_std_name                    :3:         1/2
#         var_units                       :3:         0/1
#     site_lat                            :3:       3/3
#         var_std_name                    :3:         2/2
#         var_units                       :3:         1/1
#     site_lon                            :3:       3/3
#         var_std_name                    :3:         2/2
#         var_units                       :3:         1/1
#     site_netCode                        :3:       1/3
#         var_std_name                    :3:         1/2
#         var_units                       :3:         0/1
#     time                                :3:       2/3
#         var_std_name                    :3:         2/2
#         var_units                       :3:         0/1
#     u                                   :3:       2/3
#         var_std_name                    :3:         1/2
#         var_units                       :3:         1/1
#     v                                   :3:       2/3
#         var_std_name                    :3:         1/2
#         var_units                       :3:         1/1
#
#
#                                 Medium Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# acknowledgment/acknowledgement          :2:     0/1
# comment                                 :2:     0/1
# creator_email                           :2:     1/1
# creator_name                            :2:     1/1
# creator_url                             :2:     1/1
# date_created                            :2:     0/1
# date_issued_is_iso                      :2:     0/0
# date_metadata_modified_is_iso           :2:     0/0
# date_modified_is_iso                    :2:     0/0
# geospatial_bounds                       :2:     0/1
# geospatial_bounds_crs                   :2:     0/1
# geospatial_bounds_vertical_crs          :2:     0/1
# geospatial_lat_extents_match            :2:     2/2
# geospatial_lat_max                      :2:     1/1
# geospatial_lat_min                      :2:     1/1
# geospatial_lon_extents_match            :2:     2/2
# geospatial_lon_max                      :2:     1/1
# geospatial_lon_min                      :2:     1/1
# geospatial_vertical_max                 :2:     0/1
# geospatial_vertical_min                 :2:     0/1
# geospatial_vertical_positive            :2:     0/1
# history                                 :2:     1/1
# id                                      :2:     0/1
# id_has_no_blanks                        :2:     0/0
# institution                             :2:     1/1
# instrument_uses_vocab                   :2:     0/0
# license                                 :2:     0/1
# metadata_link                           :2:     0/1
# naming_authority                        :2:     0/1
# platform_uses_vocab                     :2:     0/0
# processing_level                        :2:     0/1
# project                                 :2:     0/1
# publisher_email                         :2:     0/1
# publisher_name                          :2:     0/1
# publisher_url                           :2:     0/1
# source                                  :2:     1/1
# standard_name_vocabulary                :2:     0/1
# time_coverage_duration                  :2:     0/1
# time_coverage_end                       :2:     0/1
# time_coverage_resolution                :2:     0/1
# time_coverage_start                     :2:     0/1
# time_extents                            :2:     0/0
# vertical_extents                        :2:     0/0
#
#
#                                   Low Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# cdm_data_type                           :1:     0/2
# contributor_name                        :1:     0/1
# contributor_role                        :1:     0/1
# creator_institution                     :1:     0/1
# creator_type                            :1:     0/2
# date_issued                             :1:     0/1
# date_metadata_modified                  :1:     0/1
# date_modified                           :1:     0/1
# geospatial_lat_resolution               :1:     0/1
# geospatial_lat_units                    :1:     0/1
# geospatial_lon_resolution               :1:     0/1
# geospatial_lon_units                    :1:     0/1
# geospatial_vertical_resolution          :1:     0/1
# geospatial_vertical_units               :1:     0/1
# instrument                              :1:     0/1
# instrument_vocabulary                   :1:     0/1
# keywords_vocabulary                     :1:     0/1
# platform                                :1:     0/1
# platform_vocabulary                     :1:     0/1
# product_version                         :1:     1/1
# program                                 :1:     0/1
# publisher_institution                   :1:     0/1
# publisher_type                          :1:     0/2
# references                              :1:     1/1
#
#
# --------------------------------------------------------------------------------
#                   Reasoning for the failed tests given below:
#
#
# Name                             Priority:     Score:Reasoning
# --------------------------------------------------------------------------------
# Conventions                            :3:     1/ 2 : Attr Conventions does not
#                                                       contain 'ACDD-1.3'
# keywords                               :3:     0/ 1 : Attr keywords not present
# varattr                                :3:    21/37 :
#     DOPx                               :3:     1/ 3 :
#         var_std_name                   :3:     1/ 2 : Var DOPx missing attr
#                                                       standard_name
#         var_units                      :3:     0/ 1 : Var DOPx missing attr
#                                                       units
#     DOPy                               :3:     1/ 3 :
#         var_std_name                   :3:     1/ 2 : Var DOPy missing attr
#                                                       standard_name
#         var_units                      :3:     0/ 1 : Var DOPy missing attr
#                                                       units
#     lat                                :3:     2/ 4 :
#         coverage_content_type          :3:     0/ 1 : Var lat missing attr
#                                                       coverage_content_type
#         var_std_name                   :3:     1/ 2 : Var lat missing attr
#                                                       long_name
#     lon                                :3:     2/ 3 :
#         var_std_name                   :3:     1/ 2 : Var lon missing attr
#                                                       long_name
#     procParams                         :3:     1/ 3 :
#         var_std_name                   :3:     1/ 2 : Var procParams missing
#                                                       attr standard_name
#         var_units                      :3:     0/ 1 : Var procParams missing
#                                                       attr units
#     site_code                          :3:     1/ 3 :
#         var_std_name                   :3:     1/ 2 : Var site_code missing attr
#                                                       standard_name
#         var_units                      :3:     0/ 1 : Var site_code missing attr
#                                                       units
#     site_netCode                       :3:     1/ 3 :
#         var_std_name                   :3:     1/ 2 : Var site_netCode missing
#                                                       attr standard_name
#         var_units                      :3:     0/ 1 : Var site_netCode missing
#                                                       attr units
#     time                               :3:     2/ 3 :
#         var_units                      :3:     0/ 1 : Var time missing attr
#                                                       units
#     u                                  :3:     2/ 3 :
#         var_std_name                   :3:     1/ 2 : Var u missing attr
#                                                       long_name
#     v                                  :3:     2/ 3 :
#         var_std_name                   :3:     1/ 2 : Var v missing attr
#                                                       long_name
# acknowledgment/acknowledgement         :2:     0/ 1 :
# comment                                :2:     0/ 1 : Attr comment not present
# date_created                           :2:     0/ 1 : Attr date_created not
#                                                       present
# geospatial_bounds                      :2:     0/ 1 : Attr geospatial_bounds not
#                                                       present
# geospatial_bounds_crs                  :2:     0/ 1 : Attr geospatial_bounds_crs
#                                                       not present
# geospatial_bounds_vertical_crs         :2:     0/ 1 : Attr
#                                                       geospatial_bounds_vertical
#                                                       _crs not present
# geospatial_vertical_max                :2:     0/ 1 : Attr
#                                                       geospatial_vertical_max
#                                                       not present
# geospatial_vertical_min                :2:     0/ 1 : Attr
#                                                       geospatial_vertical_min
#                                                       not present
# geospatial_vertical_positive           :2:     0/ 1 : Attr
#                                                       geospatial_vertical_positi
#                                                       ve not present
# id                                     :2:     0/ 1 : Attr id not present
# license                                :2:     0/ 1 : Attr license not present
# metadata_link                          :2:     0/ 1 : Attr metadata_link not
#                                                       present
# naming_authority                       :2:     0/ 1 : Attr naming_authority not
#                                                       present
# processing_level                       :2:     0/ 1 : Attr processing_level not
#                                                       present
# project                                :2:     0/ 1 : Attr project not present
# publisher_email                        :2:     0/ 1 : Attr publisher_email not
#                                                       present
# publisher_name                         :2:     0/ 1 : Attr publisher_name not
#                                                       present
# publisher_url                          :2:     0/ 1 : Attr publisher_url not
#                                                       present
# standard_name_vocabulary               :2:     0/ 1 : Attr
#                                                       standard_name_vocabulary
#                                                       not present
# time_coverage_duration                 :2:     0/ 1 : Attr
#                                                       time_coverage_duration not
#                                                       present
# time_coverage_end                      :2:     0/ 1 : Attr time_coverage_end not
#                                                       present
# time_coverage_resolution               :2:     0/ 1 : Attr
#                                                       time_coverage_resolution
#                                                       not present
# time_coverage_start                    :2:     0/ 1 : Attr time_coverage_start
#                                                       not present
# cdm_data_type                          :1:     0/ 2 : Attr cdm_data_type not
#                                                       present
# contributor_name                       :1:     0/ 1 : Attr contributor_name not
#                                                       present
# contributor_role                       :1:     0/ 1 : Attr contributor_role not
#                                                       present
# creator_institution                    :1:     0/ 1 : Attr creator_institution
#                                                       not present
# creator_type                           :1:     0/ 2 : Attr creator_type not
#                                                       present
# date_issued                            :1:     0/ 1 : Attr date_issued not
#                                                       present
# date_metadata_modified                 :1:     0/ 1 : Attr
#                                                       date_metadata_modified not
#                                                       present
# date_modified                          :1:     0/ 1 : Attr date_modified not
#                                                       present
# geospatial_lat_resolution              :1:     0/ 1 : Attr
#                                                       geospatial_lat_resolution
#                                                       not present
# geospatial_lat_units                   :1:     0/ 1 : Attr geospatial_lat_units
#                                                       not present
# geospatial_lon_resolution              :1:     0/ 1 : Attr
#                                                       geospatial_lon_resolution
#                                                       not present
# geospatial_lon_units                   :1:     0/ 1 : Attr geospatial_lon_units
#                                                       not present
# geospatial_vertical_resolution         :1:     0/ 1 : Attr
#                                                       geospatial_vertical_resolu
#                                                       tion not present
# geospatial_vertical_units              :1:     0/ 1 : Attr
#                                                       geospatial_vertical_units
#                                                       not present
# instrument                             :1:     0/ 1 : Attr instrument not
#                                                       present
# instrument_vocabulary                  :1:     0/ 1 : Attr instrument_vocabulary
#                                                       not present
# keywords_vocabulary                    :1:     0/ 1 : Attr keywords_vocabulary
#                                                       not present
# platform                               :1:     0/ 1 : Attr platform not present
# platform_vocabulary                    :1:     0/ 1 : Attr platform_vocabulary
#                                                       not present
# program                                :1:     0/ 1 : Attr program not present
# publisher_institution                  :1:     0/ 1 : Attr publisher_institution
#                                                       not present
# publisher_type                         :1:     0/ 2 : Attr publisher_type not
#                                                       present
#
#
# --------------------------------------------------------------------------------
#                      The dataset scored 75 out of 83 points
#                               during the cf check
# --------------------------------------------------------------------------------
#                            Verbose Scoring Breakdown:
#
#                                  High Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# §2.2 Valid netCDF data types            :3:    12/12
# §2.3 Legal variable names               :3:    12/12
# §2.4 Unique dimensions                  :3:    12/12
# §2.6.1 Global Attribute Conventions inc :3:     0/1
# §2.6.2 Convention Attributes            :3:     5/5
#     §2.6.2 Description of file contents :3:       3/3
#         comment                         :3:         3/3
#     §2.6.2 Title/history global attribu :3:       2/2
#         history                         :3:         1/1
#         title                           :3:         1/1
# §3.1 Variables contain valid CF Units   :3:     0/1
# §3.1 Variables contain valid units for  :3:     6/6
# §3.3 Standard Names                     :3:     7/7
# §3.4 Ancillary Variables                :3:     2/2
#     u                                   :3:       1/1
#     v                                   :3:       1/1
# §4 Coordinate Variable latitude contain :3:     2/2
# §4 Coordinate Variable longitude contai :3:     2/2
# §4.4 Time coordinate variable and attri :3:     0/1
#
#
#                                 Medium Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# all_features_are_same_type              :2:     0/0
# contiguous_ragged_array                 :2:     0/0
# coordinates_and_metadata                :2:     0/0
# feature_type                            :2:     0/0
# incomplete_multidim_array               :2:     0/0
# indexed_ragged_array                    :2:     0/0
# missing_data                            :2:     0/0
# orthogonal_multidim_array               :2:     0/0
# §4 Coordinate Variables                 :2:     3/3
# §4.1 Coordinates representing latitude  :2:     6/6
# §4.1 Coordinates representing longitude :2:     6/6
# §5.1 Geophysical variables contain vali :2:     0/5
#
#
#                                   Low Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# §2.3 Unique variable names              :1:    12/12
# §2.4 Dimension order                    :1:    24/24
# §4.4.1 Time and calendar                :1:     0/1
#
#
# --------------------------------------------------------------------------------
#                   Reasoning for the failed tests given below:
#
#
# Name                             Priority:     Score:Reasoning
# --------------------------------------------------------------------------------
# §2.6.1 Global Attribute Conventions inc:3:     0/ 1 : Conventions field is not
#                                                       "CF-1.6"
# §3.1 Variables contain valid CF Units  :3:     0/ 1 : unknown units type (None)
#                                                       for procParams
# §4.4 Time coordinate variable and attri:3:     0/ 1 : time does not have units
# §5.1 Geophysical variables contain vali:2:     0/ 5 : The time dimension for the
#                                                       variable time does not
#                                                       have an associated
#                                                       coordinate variable, but
#                                                       is a Lat/Lon/Time/Height
#                                                       dimension., The time
#                                                       dimension for the variable
#                                                       u does not have an
#                                                       associated coordinate
#                                                       variable, but is a
#                                                       Lat/Lon/Time/Height
#                                                       dimension., The time
#                                                       dimension for the variable
#                                                       v does not have an
#                                                       associated coordinate
#                                                       variable, but is a
#                                                       Lat/Lon/Time/Height
#                                                       dimension., The time
#                                                       dimension for the variable
#                                                       DOPx does not have an
#                                                       associated coordinate
#                                                       variable, but is a
#                                                       Lat/Lon/Time/Height
#                                                       dimension., The time
#                                                       dimension for the variable
#                                                       DOPy does not have an
#                                                       associated coordinate
#                                                       variable, but is a
#                                                       Lat/Lon/Time/Height
#                                                       dimension.
# §4.4.1 Time and calendar               :1:     0/ 1 : Variable time should have
#                                                       a calendar attribute
# WARNING: The following exceptions occured during the cf checker (possibly indicate compliance checker issues):
# cf.check_packed_data: 'module' object has no attribute 'float128'
#   File "C:\Users\jennifer.bosch\AppData\Local\Continuum\Miniconda2\envs\I\lib\site-packages\compliance_checker\cf\cf.py", line 2378, in check_packed_data
#     if not type(scale_factor) in [np.float, np.float16, np.float32, np.float64, np.float128]:

# %% [markdown]
# ### Running Compliance Checker on Scripps THREDDS data

# %%
# Run cf and adcc checks with normal strictness, verbose text format to stdout
return_value, errors = ComplianceChecker.run_checker(SIO_HFR_path,
                           ['cf', 'acdd'], True, 'normal', '-', 'text')
# Out:
# --------------------------------------------------------------------------------
#                      The dataset scored 49 out of 85 points
#                              during the acdd check
# --------------------------------------------------------------------------------
#                            Verbose Scoring Breakdown:
#
#                                  High Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# Conventions                             :3:     1/2
# keywords                                :3:     0/1
# summary                                 :3:     1/1
# title                                   :3:     1/1
# varattr                                 :3:    32/43
#     DOPx                                :3:       1/3
#         var_std_name                    :3:         1/2
#         var_units                       :3:         0/1
#     DOPy                                :3:       1/3
#         var_std_name                    :3:         1/2
#         var_units                       :3:         0/1
#     lat                                 :3:       3/3
#         var_std_name                    :3:         2/2
#         var_units                       :3:         1/1
#     lon                                 :3:       3/3
#         var_std_name                    :3:         2/2
#         var_units                       :3:         1/1
#     procParams                          :3:       1/3
#         var_std_name                    :3:         1/2
#         var_units                       :3:         0/1
#     site_code                           :3:       1/3
#         var_std_name                    :3:         1/2
#         var_units                       :3:         0/1
#     site_lat                            :3:       3/4
#         coverage_content_type           :3:         0/1
#         var_std_name                    :3:         2/2
#         var_units                       :3:         1/1
#     site_lon                            :3:       3/3
#         var_std_name                    :3:         2/2
#         var_units                       :3:         1/1
#     site_netCode                        :3:       1/3
#         var_std_name                    :3:         1/2
#         var_units                       :3:         0/1
#     time                                :3:       3/3
#         var_std_name                    :3:         2/2
#         var_units                       :3:         1/1
#     time_offset                         :3:       3/3
#         var_std_name                    :3:         2/2
#         var_units                       :3:         1/1
#     time_run                            :3:       3/3
#         var_std_name                    :3:         2/2
#         var_units                       :3:         1/1
#     u                                   :3:       3/3
#         var_std_name                    :3:         2/2
#         var_units                       :3:         1/1
#     v                                   :3:       3/3
#         var_std_name                    :3:         2/2
#         var_units                       :3:         1/1
#
#
#                                 Medium Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# acknowledgment/acknowledgement          :2:     0/1
# comment                                 :2:     0/1
# creator_email                           :2:     1/1
# creator_name                            :2:     1/1
# creator_url                             :2:     1/1
# date_created                            :2:     0/1
# date_issued_is_iso                      :2:     0/0
# date_metadata_modified_is_iso           :2:     0/0
# date_modified_is_iso                    :2:     0/0
# geospatial_bounds                       :2:     0/1
# geospatial_bounds_crs                   :2:     0/1
# geospatial_bounds_vertical_crs          :2:     0/1
# geospatial_lat_extents_match            :2:     2/2
# geospatial_lat_max                      :2:     1/1
# geospatial_lat_min                      :2:     1/1
# geospatial_lon_extents_match            :2:     2/2
# geospatial_lon_max                      :2:     1/1
# geospatial_lon_min                      :2:     1/1
# geospatial_vertical_max                 :2:     0/1
# geospatial_vertical_min                 :2:     0/1
# geospatial_vertical_positive            :2:     0/1
# history                                 :2:     1/1
# id                                      :2:     0/1
# id_has_no_blanks                        :2:     0/0
# institution                             :2:     1/1
# instrument_uses_vocab                   :2:     0/0
# license                                 :2:     0/1
# metadata_link                           :2:     0/1
# naming_authority                        :2:     0/1
# platform_uses_vocab                     :2:     0/0
# processing_level                        :2:     0/1
# project                                 :2:     0/1
# publisher_email                         :2:     0/1
# publisher_name                          :2:     0/1
# publisher_url                           :2:     0/1
# source                                  :2:     1/1
# standard_name_vocabulary                :2:     0/1
# time_coverage_duration                  :2:     0/1
# time_coverage_end                       :2:     0/1
# time_coverage_resolution                :2:     0/1
# time_coverage_start                     :2:     0/1
# time_extents                            :2:     0/0
# vertical_extents                        :2:     0/0
#
#
#                                   Low Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# cdm_data_type                           :1:     1/2
# contributor_name                        :1:     0/1
# contributor_role                        :1:     0/1
# creator_institution                     :1:     0/1
# creator_type                            :1:     0/2
# date_issued                             :1:     0/1
# date_metadata_modified                  :1:     0/1
# date_modified                           :1:     0/1
# geospatial_lat_resolution               :1:     0/1
# geospatial_lat_units                    :1:     0/1
# geospatial_lon_resolution               :1:     0/1
# geospatial_lon_units                    :1:     0/1
# geospatial_vertical_resolution          :1:     0/1
# geospatial_vertical_units               :1:     0/1
# instrument                              :1:     0/1
# instrument_vocabulary                   :1:     0/1
# keywords_vocabulary                     :1:     0/1
# platform                                :1:     0/1
# platform_vocabulary                     :1:     0/1
# product_version                         :1:     1/1
# program                                 :1:     0/1
# publisher_institution                   :1:     0/1
# publisher_type                          :1:     0/2
# references                              :1:     1/1
#
#
# --------------------------------------------------------------------------------
#                   Reasoning for the failed tests given below:
#
#
# Name                             Priority:     Score:Reasoning
# --------------------------------------------------------------------------------
# Conventions                            :3:     1/ 2 : Attr Conventions does not
#                                                       contain 'ACDD-1.3'
# keywords                               :3:     0/ 1 : Attr keywords not present
# varattr                                :3:    32/43 :
#     DOPx                               :3:     1/ 3 :
#         var_std_name                   :3:     1/ 2 : Var DOPx missing attr
#                                                       standard_name
#         var_units                      :3:     0/ 1 : Var DOPx missing attr
#                                                       units
#     DOPy                               :3:     1/ 3 :
#         var_std_name                   :3:     1/ 2 : Var DOPy missing attr
#                                                       standard_name
#         var_units                      :3:     0/ 1 : Var DOPy missing attr
#                                                       units
#     procParams                         :3:     1/ 3 :
#         var_std_name                   :3:     1/ 2 : Var procParams missing
#                                                       attr standard_name
#         var_units                      :3:     0/ 1 : Var procParams missing
#                                                       attr units
#     site_code                          :3:     1/ 3 :
#         var_std_name                   :3:     1/ 2 : Var site_code missing attr
#                                                       standard_name
#         var_units                      :3:     0/ 1 : Var site_code missing attr
#                                                       units
#     site_lat                           :3:     3/ 4 :
#         coverage_content_type          :3:     0/ 1 : Var site_lat missing attr
#                                                       coverage_content_type
#     site_netCode                       :3:     1/ 3 :
#         var_std_name                   :3:     1/ 2 : Var site_netCode missing
#                                                       attr standard_name
#         var_units                      :3:     0/ 1 : Var site_netCode missing
#                                                       attr units
# acknowledgment/acknowledgement         :2:     0/ 1 :
# comment                                :2:     0/ 1 : Attr comment not present
# date_created                           :2:     0/ 1 : Attr date_created not
#                                                       present
# geospatial_bounds                      :2:     0/ 1 : Attr geospatial_bounds not
#                                                       present
# geospatial_bounds_crs                  :2:     0/ 1 : Attr geospatial_bounds_crs
#                                                       not present
# geospatial_bounds_vertical_crs         :2:     0/ 1 : Attr
#                                                       geospatial_bounds_vertical
#                                                       _crs not present
# geospatial_vertical_max                :2:     0/ 1 : Attr
#                                                       geospatial_vertical_max
#                                                       not present
# geospatial_vertical_min                :2:     0/ 1 : Attr
#                                                       geospatial_vertical_min
#                                                       not present
# geospatial_vertical_positive           :2:     0/ 1 : Attr
#                                                       geospatial_vertical_positi
#                                                       ve not present
# id                                     :2:     0/ 1 : Attr id not present
# license                                :2:     0/ 1 : Attr license not present
# metadata_link                          :2:     0/ 1 : Attr metadata_link not
#                                                       present
# naming_authority                       :2:     0/ 1 : Attr naming_authority not
#                                                       present
# processing_level                       :2:     0/ 1 : Attr processing_level not
#                                                       present
# project                                :2:     0/ 1 : Attr project not present
# publisher_email                        :2:     0/ 1 : Attr publisher_email not
#                                                       present
# publisher_name                         :2:     0/ 1 : Attr publisher_name not
#                                                       present
# publisher_url                          :2:     0/ 1 : Attr publisher_url not
#                                                       present
# standard_name_vocabulary               :2:     0/ 1 : Attr
#                                                       standard_name_vocabulary
#                                                       not present
# time_coverage_duration                 :2:     0/ 1 : Attr
#                                                       time_coverage_duration not
#                                                       present
# time_coverage_end                      :2:     0/ 1 : Attr time_coverage_end not
#                                                       present
# time_coverage_resolution               :2:     0/ 1 : Attr
#                                                       time_coverage_resolution
#                                                       not present
# time_coverage_start                    :2:     0/ 1 : Attr time_coverage_start
#                                                       not present
# cdm_data_type                          :1:     1/ 2 : Attr cdm_data_type
#                                                       present, but not in
#                                                       expected value list
#                                                       ([u'Grid', u'Image',
#                                                       u'Point', u'Radial',
#                                                       u'Station', u'Swath',
#                                                       u'Trajectory'])
# contributor_name                       :1:     0/ 1 : Attr contributor_name not
#                                                       present
# contributor_role                       :1:     0/ 1 : Attr contributor_role not
#                                                       present
# creator_institution                    :1:     0/ 1 : Attr creator_institution
#                                                       not present
# creator_type                           :1:     0/ 2 : Attr creator_type not
#                                                       present
# date_issued                            :1:     0/ 1 : Attr date_issued not
#                                                       present
# date_metadata_modified                 :1:     0/ 1 : Attr
#                                                       date_metadata_modified not
#                                                       present
# date_modified                          :1:     0/ 1 : Attr date_modified not
#                                                       present
# geospatial_lat_resolution              :1:     0/ 1 : Attr
#                                                       geospatial_lat_resolution
#                                                       not present
# geospatial_lat_units                   :1:     0/ 1 : Attr geospatial_lat_units
#                                                       not present
# geospatial_lon_resolution              :1:     0/ 1 : Attr
#                                                       geospatial_lon_resolution
#                                                       not present
# geospatial_lon_units                   :1:     0/ 1 : Attr geospatial_lon_units
#                                                       not present
# geospatial_vertical_resolution         :1:     0/ 1 : Attr
#                                                       geospatial_vertical_resolu
#                                                       tion not present
# geospatial_vertical_units              :1:     0/ 1 : Attr
#                                                       geospatial_vertical_units
#                                                       not present
# instrument                             :1:     0/ 1 : Attr instrument not
#                                                       present
# instrument_vocabulary                  :1:     0/ 1 : Attr instrument_vocabulary
#                                                       not present
# keywords_vocabulary                    :1:     0/ 1 : Attr keywords_vocabulary
#                                                       not present
# platform                               :1:     0/ 1 : Attr platform not present
# platform_vocabulary                    :1:     0/ 1 : Attr platform_vocabulary
#                                                       not present
# program                                :1:     0/ 1 : Attr program not present
# publisher_institution                  :1:     0/ 1 : Attr publisher_institution
#                                                       not present
# publisher_type                         :1:     0/ 2 : Attr publisher_type not
#                                                       present
#
#
# --------------------------------------------------------------------------------
#                     The dataset scored 122 out of 139 points
#                               during the cf check
# --------------------------------------------------------------------------------
#                            Verbose Scoring Breakdown:
#
#                                  High Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# §2.2 Valid netCDF data types            :3:    14/14
# §2.3 Legal variable names               :3:    14/14
# §2.4 Unique dimensions                  :3:    14/14
# §2.6.1 Global Attribute Conventions inc :3:     0/1
# §2.6.2 Convention Attributes            :3:     5/5
#     §2.6.2 Description of file contents :3:       3/3
#         comment                         :3:         3/3
#     §2.6.2 Title/history global attribu :3:       2/2
#         history                         :3:         1/1
#         title                           :3:         1/1
# §3.1 Variables contain valid CF Units   :3:     0/1
# §3.1 Variables contain valid units for  :3:     7/9
# §3.3 Standard Names                     :3:     9/9
# §3.4 Ancillary Variables                :3:     2/2
#     u                                   :3:       1/1
#     v                                   :3:       1/1
# §4 Coordinate Variable latitude contain :3:     2/2
# §4 Coordinate Variable longitude contai :3:     2/2
# §4.4 Time coordinate variable and attri :3:     6/6
# §5.2 Latitude and longitude coordinates :3:     5/5
#                                         :3:       1/1
#         coordinates_reference_itself    :3:         1/1
#     lat                                 :3:       1/1
#         coordinates_reference_itself    :3:         1/1
#     lon                                 :3:       1/1
#         coordinates_reference_itself    :3:         1/1
#     time                                :3:       1/1
#         coordinates_reference_itself    :3:         1/1
#     time_run                            :3:       1/1
#         coordinates_reference_itself    :3:         1/1
# §9.1 Feature Types are all the same     :3:     0/1
#
#
#                                 Medium Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# §4 Coordinate Variables                 :2:     3/3
# §4.1 Coordinates representing latitude  :2:     6/6
# §4.1 Coordinates representing longitude :2:     6/6
# §5.1 Geophysical variables contain vali :2:     6/6
# §5.3 Is reduced horizontal grid         :2:     0/4
#     DOPx                                :2:       0/1
#         is_reduced_horizontal_grid      :2:         0/1
#     DOPy                                :2:       0/1
#         is_reduced_horizontal_grid      :2:         0/1
#     u                                   :2:       0/1
#         is_reduced_horizontal_grid      :2:         0/1
#     v                                   :2:       0/1
#         is_reduced_horizontal_grid      :2:         0/1
# §6.2 Alternative Coordinates            :2:     1/1
#     time_run                            :2:       1/1
#         alternative_coordinates         :2:         1/1
# §9.3.1 Orthogonal Multidimensional Arra :2:    14/14
#     DOPx                                :2:       1/1
#         orthogonal_multidimensional     :2:         1/1
#     DOPy                                :2:       1/1
#         orthogonal_multidimensional     :2:         1/1
#     lat                                 :2:       1/1
#         orthogonal_multidimensional     :2:         1/1
#     lon                                 :2:       1/1
#         orthogonal_multidimensional     :2:         1/1
#     procParams                          :2:       1/1
#         orthogonal_multidimensional     :2:         1/1
#     site_code                           :2:       1/1
#         orthogonal_multidimensional     :2:         1/1
#     site_lat                            :2:       1/1
#         orthogonal_multidimensional     :2:         1/1
#     site_lon                            :2:       1/1
#         orthogonal_multidimensional     :2:         1/1
#     site_netCode                        :2:       1/1
#         orthogonal_multidimensional     :2:         1/1
#     time                                :2:       1/1
#         orthogonal_multidimensional     :2:         1/1
#     time_offset                         :2:       1/1
#         orthogonal_multidimensional     :2:         1/1
#     time_run                            :2:       1/1
#         orthogonal_multidimensional     :2:         1/1
#     u                                   :2:       1/1
#         orthogonal_multidimensional     :2:         1/1
#     v                                   :2:       1/1
#         orthogonal_multidimensional     :2:         1/1
# §9.4 featureType attribute              :2:     0/1
# §9.5 Discrete Geometry                  :2:     2/9
#     dataset                             :2:       0/1
#     procParams                          :2:       0/1
#         check_coordinates               :2:         0/1
#     site_code                           :2:       0/1
#         check_coordinates               :2:         0/1
#     site_lat                            :2:       0/1
#         check_coordinates               :2:         0/1
#     site_lon                            :2:       0/1
#         check_coordinates               :2:         0/1
#     site_netCode                        :2:       0/1
#         check_coordinates               :2:         0/1
#     time_offset                         :2:       0/1
#         check_coordinates               :2:         0/1
#     u                                   :2:       1/1
#         check_coordinates               :2:         1/1
#     v                                   :2:       1/1
#         check_coordinates               :2:         1/1
# §9.6 Missing Data                       :2:     4/4
#     DOPx                                :2:       1/1
#         missing_data                    :2:         1/1
#     DOPy                                :2:       1/1
#         missing_data                    :2:         1/1
#     u                                   :2:       1/1
#         missing_data                    :2:         1/1
#     v                                   :2:       1/1
#         missing_data                    :2:         1/1
#
#
#                                   Low Priority
# --------------------------------------------------------------------------------
#     Name                            :Priority: Score
# §2.3 Unique variable names              :1:    14/14
# §2.4 Dimension order                    :1:    28/28
# §4.4.1 Time and calendar                :1:     0/3
#
#
# --------------------------------------------------------------------------------
#                   Reasoning for the failed tests given below:
#
#
# Name                             Priority:     Score:Reasoning
# --------------------------------------------------------------------------------
# §2.6.1 Global Attribute Conventions inc:3:     0/ 1 : Conventions field is not
#                                                       "CF-1.6"
# §3.1 Variables contain valid CF Units  :3:     0/ 1 : unknown units type (None)
#                                                       for procParams
# §3.1 Variables contain valid units for :3:     7/ 9 : units are hours since
#                                                       2012-01-01T00:00:00Z,
#                                                       standard_name units should
#                                                       be s, units are hours
#                                                       since
#                                                       2012-01-01T00:00:00Z,
#                                                       standard_name units should
#                                                       be s
# §9.1 Feature Types are all the same    :3:     0/ 1 : At least one of the
#                                                       variables has a different
#                                                       feature type than the rest
#                                                       of the variables.,
#                                                       site_code(nSites,
#                                                       maxStrlen64)
#                                                       site_lon(nSites)
#                                                       procParams(nProcParam)
#                                                       u(time, lat, lon) v(time,
#                                                       lat, lon) time_run(time)
#                                                       time_offset(time)
#                                                       site_netCode(nSites,
#                                                       maxStrlen64)
#                                                       site_lat(nSites)
# §5.3 Is reduced horizontal grid        :2:     0/ 4 :
#     DOPx                               :2:     0/ 1 :
#         is_reduced_horizontal_grid     :2:     0/ 1 : Coordinate  is not a
#                                                       proper variable
#     DOPy                               :2:     0/ 1 :
#         is_reduced_horizontal_grid     :2:     0/ 1 : Coordinate  is not a
#                                                       proper variable
#     u                                  :2:     0/ 1 :
#         is_reduced_horizontal_grid     :2:     0/ 1 : Coordinate  is not a
#                                                       proper variable
#     v                                  :2:     0/ 1 :
#         is_reduced_horizontal_grid     :2:     0/ 1 : Coordinate  is not a
#                                                       proper variable
# §9.4 featureType attribute             :2:     0/ 1 : The featureType is
#                                                       provided and is not from
#                                                       the featureType list.
# §9.5 Discrete Geometry                 :2:     2/ 9 :
#     dataset                            :2:     0/ 1 : The cf_role featureType is
#                                                       not properly defined.
#     procParams                         :2:     0/ 1 :
#         check_coordinates              :2:     0/ 1 : The variable procParams
#                                                       does not have associated
#                                                       coordinates
#     site_code                          :2:     0/ 1 :
#         check_coordinates              :2:     0/ 1 : The variable site_code
#                                                       does not have associated
#                                                       coordinates
#     site_lat                           :2:     0/ 1 :
#         check_coordinates              :2:     0/ 1 : The variable site_lat does
#                                                       not have associated
#                                                       coordinates
#     site_lon                           :2:     0/ 1 :
#         check_coordinates              :2:     0/ 1 : The variable site_lon does
#                                                       not have associated
#                                                       coordinates
#     site_netCode                       :2:     0/ 1 :
#         check_coordinates              :2:     0/ 1 : The variable site_netCode
#                                                       does not have associated
#                                                       coordinates
#     time_offset                        :2:     0/ 1 :
#         check_coordinates              :2:     0/ 1 : The variable time_offset
#                                                       does not have associated
#                                                       coordinates
# §4.4.1 Time and calendar               :1:     0/ 3 : Variable time_offset
#                                                       should have a calendar
#                                                       attribute, Variable time
#                                                       should have a calendar
#                                                       attribute, Variable
#                                                       time_run should have a
#                                                       calendar attribute
